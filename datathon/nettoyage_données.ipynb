# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://gitlab.com/isnardynicolas/wcs_import/-/raw/main/tracks_features.csv")

# %%
# On récupère les types des valeurs des colonnes du data frame
def get_unique_column_types(df, col_name):
    """
    Returns a list of the unique types of values in the specified column of the DataFrame.

    Parameters:
    df (pandas.DataFrame): The DataFrame containing the column.
    col_name (str): The name of the column to check.

    Returns:
    list: A list of the unique types of values in the column.
    """
    unique_types = df[col_name].apply(type).unique()
    return unique_types

# List of column names in the DataFrame
column_names = df.columns.tolist()

# Iterate over each column name and print the unique types of values in that column
for col_name in column_names:
    types = get_unique_column_types(df, col_name)
    print(f"{col_name}' = {types}")
# Out:
# id' = [<class 'str'>]
# name' = [<class 'str'>]
# album' = [<class 'str'>]
# album_id' = [<class 'str'>]
# artists' = [<class 'str'>]
# artist_ids' = [<class 'str'>]
# track_number' = [<class 'int'>]
# disc_number' = [<class 'int'>]
# explicit' = [<class 'bool'>]
# danceability' = [<class 'float'>]
# energy' = [<class 'float'>]
# key' = [<class 'int'>]
# loudness' = [<class 'float'>]
# mode' = [<class 'int'>]
# speechiness' = [<class 'float'>]
# acousticness' = [<class 'float'>]
# instrumentalness' = [<class 'float'>]
# liveness' = [<class 'float'>]
# valence' = [<class 'float'>]
# tempo' = [<class 'float'>]
# duration_ms' = [<class 'int'>]
# time_signature' = [<class 'float'>]
# year' = [<class 'int'>]
# release_date' = [<class 'str'>]

# %%
df.nunique()
# Out:
# id                  1204025
# name                 850944
# album                106162
# album_id             118382
# artists              165365
# artist_ids           166423
# track_number             50
# disc_number              13
# explicit                  2
# danceability           1362
# energy                 3441
# key                      12
# loudness              39805
# mode                      2
# speechiness            1653
# acousticness           5398
# instrumentalness       5402
# liveness               1799
# valence                1884
# tempo                140472
# duration_ms          210013
# time_signature            5
# year                    101
# release_date          10566
# dtype: int64

# %%
# On change une valeur abérante de la colonne release_date
df.loc[df.release_date == "0000", "release_date"] = "2018-09-04"

# %%
# On change une valeur abérante de la colonne year
df.loc[df.year == 0, "year"] = 2018

# %%
# Vérification 
print((df.release_date == "0000").sum())
print((df.year == 0).sum())
# Out:
# 0
# 0

# %%
# Conversion de la colonne year en date_time
df.year = pd.to_datetime(df.year, format=  "%Y")

# %%
## Creation d'une copie pour éviter les bétises
df_copy = df.copy()

# %%
# On sélectionne les colonnes pertinantes
df_copy = df_copy[['id', 'name', 'album', 'album_id', 'artists', 'artist_ids',
       'explicit', 'danceability', 'energy',
       'loudness', 'speechiness',
       'valence', 'tempo', 'duration_ms',
       'year']]

# %%
# Création d'un masque des durées de musique supérieure à 10 min 
mask = df_copy.duration_ms > 600000
# On ne garde que les lignes qui ne sont pas dans le masque
df_copy = df_copy[~mask]

# %%
def nettoyage(artist):
    return artist.replace("[", "").replace("]", "")

df_copy.artists = df_copy.artists.apply(nettoyage)

# %%
df_copy
# Out:
#                              id                   name  \
# 0        7lmeHLHBe4nmXzuXc0HDjk                Testify
# 1        1wsRitfRRtWyEapl0q22o8        Guerrilla Radio
# 2        1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb
# 3        2lbASgTSoDO7MTuLAXlTW0              Mic Check
# 4        1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire
# ...                         ...                    ...
# 1204020  0EsMifwUmMfJZxzoMPXJKZ         Gospel of Juke
# 1204021  2WSc2TB1CSJgGE0PEzVeiu          Prism Visions
# 1204022  6iProIgUe3ETpO6UT0v5Hg              Tokyo 360
# 1204023  37B4SXC8uoBsUyKCWnhPfX                 Yummy!
# 1204024  3GgQmOxxLyRoAb4j86zOBX   That's The Way It Is
#
#                              album                album_id  \
# 0        The Battle Of Los Angeles  2eia0myWFgoHuttJytCxgX
# 1        The Battle Of Los Angeles  2eia0myWFgoHuttJytCxgX
# 2        The Battle Of Los Angeles  2eia0myWFgoHuttJytCxgX
# 3        The Battle Of Los Angeles  2eia0myWFgoHuttJytCxgX
# 4        The Battle Of Los Angeles  2eia0myWFgoHuttJytCxgX
# ...                            ...                     ...
# 1204020                 Notch - EP  38O5Ys0W9PFS5K7dMb7yKb
# 1204021                 Notch - EP  38O5Ys0W9PFS5K7dMb7yKb
# 1204022                 Notch - EP  38O5Ys0W9PFS5K7dMb7yKb
# 1204023                 Notch - EP  38O5Ys0W9PFS5K7dMb7yKb
# 1204024                 Notch - EP  38O5Ys0W9PFS5K7dMb7yKb
#
#                             artists                  artist_ids  explicit  \
# 0        'Rage Against The Machine'  ['2d0hyoQ5ynDBnkvAbJKORj']     False
# 1        'Rage Against The Machine'  ['2d0hyoQ5ynDBnkvAbJKORj']      True
# 2        'Rage Against The Machine'  ['2d0hyoQ5ynDBnkvAbJKORj']     False
# 3        'Rage Against The Machine'  ['2d0hyoQ5ynDBnkvAbJKORj']      True
# 4        'Rage Against The Machine'  ['2d0hyoQ5ynDBnkvAbJKORj']     False
# ...                             ...                         ...       ...
# 1204020                   'FVLCRVM'  ['7AjItKsRnEYRSiBt2OxK1y']     False
# 1204021                   'FVLCRVM'  ['7AjItKsRnEYRSiBt2OxK1y']     False
# 1204022                   'FVLCRVM'  ['7AjItKsRnEYRSiBt2OxK1y']     False
# 1204023                   'FVLCRVM'  ['7AjItKsRnEYRSiBt2OxK1y']     False
# 1204024                   'FVLCRVM'  ['7AjItKsRnEYRSiBt2OxK1y']     False
#
#          danceability  energy  loudness  speechiness  valence    tempo  \
# 0               0.470   0.978    -5.399       0.0727    0.503  117.906
# 1               0.599   0.957    -5.764       0.1880    0.489  103.680
# 2               0.315   0.970    -5.424       0.4830    0.370  149.749
# 3               0.440   0.967    -5.830       0.2370    0.574   96.752
# 4               0.426   0.929    -6.729       0.0701    0.539  127.059
# ...               ...     ...       ...          ...      ...      ...
# 1204020         0.264   0.966    -6.970       0.0672    0.415  159.586
# 1204021         0.796   0.701    -6.602       0.0883    0.781  121.980
# 1204022         0.785   0.796    -5.960       0.0564    0.467  121.996
# 1204023         0.665   0.856    -6.788       0.0409    0.227  124.986
# 1204024         0.736   0.708    -9.279       0.0539    0.204  117.991
#
#          duration_ms       year
# 0             210133 1999-01-01
# 1             206200 1999-01-01
# 2             298893 1999-01-01
# 3             213640 1999-01-01
# 4             205600 1999-01-01
# ...              ...        ...
# 1204020       276213 2014-01-01
# 1204021       363179 2014-01-01
# 1204022       385335 2014-01-01
# 1204023       324455 2014-01-01
# 1204024       304982 2014-01-01
#
# [1176100 rows x 15 columns]

# %%
# On exporte au format csv
df_copy.to_csv("/content/sample_data/datathonbbq.csv")

# %%
df_copy.loc[(df.name.str.contains("Thunder"))]
# Out:
#                              id                            name  \
# 1132     3EOTqLimBnBQPSx1FbSQ9w  Thunder Dreamer - Timewave Mix
# 1991     66hjtaVBwgqnaLCSVZBbwg                    Thunderstorm
# 2308     7rB3NJ9E3XVLJSs78LCM4l                     Thunderdome
# 3689     1OU0yG9QKkFflastCoyttJ                Southern Thunder
# 5339     34qaHht7RWN0c1dTj4OGKd                 Thunderbird ESQ
# ...                         ...                             ...
# 1193179  0gspEP4FV26P0ftTintsHb                         Thunder
# 1193670  1rClkLqOH3vNroWCFUAJdV                    Thunderforce
# 1195184  0Rj994GUgsxbCeBzNxAC4m                I Am the Thunder
# 1200634  1yF5Du14fgtCvokdNyhdVP            Storming The Thunder
# 1203587  1fHvDqHHT8U3wOYQydUZVC           Thunder and Lightning
#
#                                                      album  \
# 1132                                          Groove Tribe
# 1991                                            In Reverse
# 2308                                              Reforged
# 3689                                                Stormy
# 5339               The Shaw Tapes: Live In Detroit 5/27/88
# ...                                                    ...
# 1193179                                     Ears Wide Shut
# 1193670                               Juggernaut's Wrath 2
# 1195184                                         Cyberblade
# 1200634  The Cosmic Waters (Inspired by 'The Outlaw Oce...
# 1203587                                           Hoffnung
#
#                        album_id                     artists  \
# 1132     4Arv2qXssKmDhOxKW9pUcO      'David & Steve Gordon'
# 1991     6eW8RSaJVFcCgV7DuLWVan             'Matthew Sweet'
# 2308     2XxqVEbpSvDGo2J3PqFDVg                 'Zephaniah'
# 3689     0RpjVT5m7uCwjcMlvy7K47        'Hank Williams, Jr.'
# 5339     4zBL0rHt9dTxOghha5O94D                'The Gories'
# ...                         ...                         ...
# 1193179  3Syfmr4LIs7Ubn9z9JrzCi               'The A-Bones'
# 1193670  00jsLpp6VXQpcXzU1hP5Gt   'Revolt Production Music'
# 1195184  0ql0CrhFAGBMpNHp0u43km            'Shadow Warrior'
# 1200634  5euL6qFngzBF3uEXB8AnhV  'Televangel', 'Ian Urbina'
# 1203587  409B6xss45zK9olos5z8P6                 'Lacrimosa'
#
#                                                 artist_ids  explicit  \
# 1132                            ['4yt002Vil1q4Vl9JOx48QG']     False
# 1991                            ['2idymNTKUdnTxforkb12Mw']     False
# 2308                            ['7JZhOvH58gTVYLaX5WOVwR']     False
# 3689                            ['2dyeCWctcFRt3Pha76ONgb']     False
# 5339                            ['5tcr1ujTO3Q0WH2wkY7RWh']     False
# ...                                                    ...       ...
# 1193179                         ['1HJKMokVRiiUSsjfubhtKq']     False
# 1193670                         ['5aYAUA8CBgKOAhAmjEg9ra']     False
# 1195184                         ['77J5B6M4wJesuY3QDKjGUI']     False
# 1200634  ['2J6cJXIuA7tHufujlMnrKF', '7miGJahGF5JYOunptm...     False
# 1203587                         ['57ekbx9PSS4ORs5wTZMSYp']     False
#
#          danceability  energy  loudness  speechiness  valence    tempo  \
# 1132            0.769   0.849   -10.378       0.0393   0.7020  124.005
# 1991            0.270   0.665    -6.969       0.0441   0.3620  100.422
# 2308            0.266   0.970    -3.836       0.1120   0.2850   90.084
# 3689            0.636   0.793    -3.770       0.0299   0.5790   93.015
# 5339            0.591   0.861    -8.047       0.0467   0.7930   92.365
# ...               ...     ...       ...          ...      ...      ...
# 1193179         0.248   0.807    -8.276       0.0447   0.6400  156.669
# 1193670         0.358   0.913    -9.280       0.0627   0.1010  149.932
# 1195184         0.588   0.976    -8.028       0.0842   0.0396  119.950
# 1200634         0.573   0.558   -10.148       0.0305   0.1270  146.022
# 1203587         0.513   0.891    -6.107       0.0707   0.3780  125.991
#
#          duration_ms       year
# 1132          285302 2011-01-01
# 1991          577773 1999-01-01
# 2308          290149 2016-01-01
# 3689          300493 1999-01-01
# 5339          150413 2013-01-01
# ...              ...        ...
# 1193179       179053 2014-01-01
# 1193670       158857 2016-01-01
# 1195184       268513 2020-01-01
# 1200634       289315 2020-01-01
# 1203587       235413 2015-01-01
#
# [627 rows x 15 columns]
